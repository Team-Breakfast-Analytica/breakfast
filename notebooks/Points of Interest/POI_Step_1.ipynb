# %% [raw]
# Proximity to Recreational Points of Interest Part 1

# %%
#Importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
#Read in the Points of Interest
poi=pd.read_csv('assets/seattle_poi_apr2022_v4.csv')

# %%
poi.head()
# Out:
#                                  Title  \
# 0     A Sound Garden by Douglas Hollis
# 1  Airport Playground at Magnuson Park
# 2       11th Avenue NW Street End Park
# 3                12th Ave. S Viewpoint
# 4                12th Ave. Square Park
#
#                               Coordinates      Reviews Review_Points  \
# 0   47.68565569048947, -122.2490482370384  101 reviews           4.2
# 1  47.681989265242954, -122.2576847597763   58 reviews           4.6
# 2  47.65983440832136, -122.37030907511918   10 reviews           4.7
# 3  47.57806492991783, -122.31743767272148  152 reviews           4.3
# 4  47.60741211542865, -122.31582245792956   10 reviews           3.7
#
#                                              Address      Website  \
# 0          7600 Sand Point Way NE, Seattle, WA 98115  seattle.gov
# 1            The Brig, NE 74th St, Seattle, WA 98115  seattle.gov
# 2  11th Avenue Northwest Street End, 11th Ave NW,...  seattle.gov
# ...

# %%
#Convert Latitude and Longitude from String to Precision Float
pd.set_option('display.precision',15)
poi[['lat2', 'lon2']]=poi['Coordinates'].str.split(', ', expand=True)
poi.lat2 = poi.lat2.astype(float)
poi.lon2 = poi.lon2.astype(float)
poi_coordinates=poi.drop(['Coordinates'], axis=1)

# %%
poi_coordinates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          870 non-null    object
#  1   Reviews        870 non-null    object
#  2   Review_Points  870 non-null    object
#  3   Address        870 non-null    object
#  4   Website        870 non-null    object
#  5   Phone          870 non-null    object
#  6   Category       870 non-null    object
#  7   lat2           870 non-null    float64
#  8   lon2           870 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 61.3+ KB

# %%
#poi_coordinates=poi_coordinates[['Title', 'lat2', 'lon2']]
poi_coordinates.head()
# Out:
#                                  Title      Reviews Review_Points  \
# 0     A Sound Garden by Douglas Hollis  101 reviews           4.2
# 1  Airport Playground at Magnuson Park   58 reviews           4.6
# 2       11th Avenue NW Street End Park   10 reviews           4.7
# 3                12th Ave. S Viewpoint  152 reviews           4.3
# 4                12th Ave. Square Park   10 reviews           3.7
#
#                                              Address      Website  \
# 0          7600 Sand Point Way NE, Seattle, WA 98115  seattle.gov
# 1            The Brig, NE 74th St, Seattle, WA 98115  seattle.gov
# 2  11th Avenue Northwest Street End, 11th Ave NW,...  seattle.gov
# 3                 2821 12th Ave S, Seattle, WA 98144  seattle.gov
# 4                    564 12th Ave, Seattle, WA 98122  seattle.gov
#
#             Phone    Category                lat2                 lon2
# 0   Not Available   Sculpture  47.685655690489469 -122.249048237038394
# ...

# %%
#poi_coordinates=poi_coordinates.dropna()
poi_coordinates.tail()
# Out:
#                         Title      Reviews Review_Points  \
# 865      Mount Si Golf Course  407 reviews           4.4
# 866   Twin Rivers Golf Course  130 reviews           3.9
# 867         Aldarra Golf Club   71 reviews           4.8
# 868  Harbour Pointe Golf Club  280 reviews           4.1
# 869  West Seattle Golf Course  354 reviews           4.2
#
#                                                Address  \
# 865           9010 Boalch Ave SE, Snoqualmie, WA 98065
# 866  4446 Preston-Fall City Rd SE, Fall City, WA 98024
# 867       29125 SE Duthie Hill Rd, Sammamish, WA 98075
# 868      11817 Harbour Pointe Blvd, Mukilteo, WA 98275
# 869                4470 35th Ave SW, Seattle, WA 98126
#
#                       Website           Phone             Category  \
# 865              mtsigolf.com  (425) 391-4926          Golf Course
# 866  twinriversgolfcourse.com  (425) 222-7575          Golf Course
# 867       aldarragolfclub.com  (425) 222-7828  Private Golf Course
# ...

# %%
poi_coordinates.columns
# Out:
# Index(['Title', 'Reviews', 'Review_Points', 'Address', 'Website', 'Phone',
#        'Category', 'lat2', 'lon2'],
#       dtype='object')

# %%
#Reading the Seattle Airbnb listings summary file and column selection; cleanup names
cols = [0,4,6,7]
names = ['id','neighborhood_group','lat1','lon1']
df_air = pd.read_csv('assets/seattle-listings.csv', header=1 ,skiprows=[0],engine='python', sep=',', usecols = cols, names= names)

# data preparation cleanup on data_airbnb_all data set
df_air = df_air.apply(lambda x: x.astype(str).str.upper())
df_air = df_air.reset_index(drop=True)
df_air
# Out:
#             id   neighborhood_group         lat1          lon1
# 0         9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# 1         9531         WEST SEATTLE     47.55495    -122.38663
# 2         9534         WEST SEATTLE     47.55627    -122.38607
# 3         9596  OTHER NEIGHBORHOODS     47.65608    -122.33602
# 4         9909         WEST SEATTLE     47.56612    -122.37273
# ...        ...                  ...          ...           ...
# 4679  53868263  OTHER NEIGHBORHOODS  47.65281967  -122.3422104
# 4680  53881175         CENTRAL AREA  47.61082921  -122.3143025
# 4681  53893335         CENTRAL AREA  47.60199141  -122.2989497
# 4682  53901135             DELRIDGE  47.54474519  -122.3559321
# 4683  53904424             DOWNTOWN  47.61458281  -122.3485242
#
# [4684 rows x 4 columns]

# %%
#import packages
import psycopg2
#import pandas as pd
from sqlalchemy import create_engine

# establish connections
conn_string = 'postgresql://jthkkecjvhqeso:c4615974e5b0f0e0424e8a84c51bf107d32bcff42927afa2285015e628b8b4bd@ec2-52-201-124-168.compute-1.amazonaws.com:5432/db6idd99el978g'

# create the engine with the connection string
db = create_engine(conn_string)

# this makes the connection to the PostgreSQL database
conn = db.connect()

# these are the credentials necessary to work with the PostgreSQL database
conn1 = psycopg2.connect(database='db6idd99el978g', user='jthkkecjvhqeso',
                         password='c4615974e5b0f0e0424e8a84c51bf107d32bcff42927afa2285015e628b8b4bd',
                         host='ec2-52-201-124-168.compute-1.amazonaws.com',
                         port= '5432')

conn1.autocommit = True

# create a cursor object
cursor = conn1.cursor()

# drop table if it already exists
#cursor.execute('drop table if exists points of interest')
cursor.execute('drop table if exists points_of_interest')

# create the SQL table – pick a unique name (don’t use dashes if more than one word
# use only underscores such as seattle_data or below is crime_clusters)
sql = '''CREATE TABLE points_of_interest(Title varchar(128),Category varchar(128),Address varchar(128),Phone varchar(128),Website varchar(128),Reviews varchar(128),Review_points varchar(128),lat2 varchar(128),long2 varchar(128));'''


# use cursor object to execute the sql create table command
cursor.execute(sql)

# converting data from pandas dataframe to sql
poi_coordinates.to_sql('points_of_interest', conn, if_exists= 'replace')

# fetching all rows
sql1='''select * from points_of_interest;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)

# committing data from connection
conn1.commit()

# close connection to the postgresql database
conn1.close()
# Out:
# (0, 'A Sound Garden by Douglas Hollis', '101 reviews', '4.2', '7600 Sand Point Way NE, Seattle, WA 98115', 'seattle.gov', 'Not Available', 'Sculpture', 47.68565569048947, -122.2490482370384)
# (1, 'Airport Playground at Magnuson Park', '58 reviews', '4.6', 'The Brig, NE 74th St, Seattle, WA 98115', 'seattle.gov', '(206) 684-4946', 'Playground', 47.681989265242954, -122.2576847597763)
# (2, '11th Avenue NW Street End Park', '10 reviews', '4.7', '11th Avenue Northwest Street End, 11th Ave NW, Seattle, WA 98107', 'seattle.gov', '(206) 386-4575', 'Park', 47.65983440832136, -122.37030907511918)
# (3, '12th Ave. S Viewpoint', '152 reviews', '4.3', '2821 12th Ave S, Seattle, WA 98144', 'seattle.gov', '(206) 684-4075', 'Park', 47.57806492991783, -122.31743767272148)
# (4, '12th Ave. Square Park', '10 reviews', '3.7', '564 12th Ave, Seattle, WA 98122', 'seattle.gov', '(206) 684-4075', 'Park', 47.60741211542865, -122.31582245792956)
# ...

# %%
# import libraries
from geopy.distance import geodesic
import pandas as pd
import numpy as np

# Merge the two dataframes first
df_all = pd.merge(df_air.assign(key=0), poi_coordinates.assign(key=0), on='key').drop('key', axis=1)

# Calculate the distance between each pair of points using apply with vincenty.
df_all['miles'] = df_all.apply((lambda row: geodesic((
                row['lat1'], row['lon1']),(
                row['lat2'], row['lon2'])).miles),axis=1)

df_all
# Out:
#                id   neighborhood_group         lat1          lon1  \
# 0            9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# 1            9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# 2            9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# 3            9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# 4            9419  OTHER NEIGHBORHOODS     47.55017    -122.31937
# ...           ...                  ...          ...           ...
# 4075075  53904424             DOWNTOWN  47.61458281  -122.3485242
# 4075076  53904424             DOWNTOWN  47.61458281  -122.3485242
# 4075077  53904424             DOWNTOWN  47.61458281  -122.3485242
# 4075078  53904424             DOWNTOWN  47.61458281  -122.3485242
# 4075079  53904424             DOWNTOWN  47.61458281  -122.3485242
#
#                                        Title      Reviews Review_Points  \
# 0           A Sound Garden by Douglas Hollis  101 reviews           4.2
# ...

# %%
df_all.to_csv('assets/distances_all_airbnb_all_poi.csv')

# %%
#Proceed to POI_Step_2.ipynb
