# %% [raw]
# Proximity to Recreational Points of Interest Part 2

# %%
#Importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
#Read in the output from POI_Step_1.ipynb
df_all=pd.read_csv('assets/distances_all_airbnb_all_poi.csv')
df_all
# Out:
#          Unnamed: 0        id   neighborhood_group       lat1        lon1  \
# 0                 0      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 1                 1      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 2                 2      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 3                 3      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 4                 4      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# ...             ...       ...                  ...        ...         ...
# 4075075     4075075  53904424             DOWNTOWN  47.614583 -122.348524
# 4075076     4075076  53904424             DOWNTOWN  47.614583 -122.348524
# 4075077     4075077  53904424             DOWNTOWN  47.614583 -122.348524
# 4075078     4075078  53904424             DOWNTOWN  47.614583 -122.348524
# 4075079     4075079  53904424             DOWNTOWN  47.614583 -122.348524
#
#                                        Title      Reviews Review_Points  \
# ...

# %%
#count the number of restaurants/points of interest within each distance threshold.
within_quarter=df_all[df_all['miles'] <=.25]
within_half=df_all[df_all['miles'] <=.5]
within_one=df_all[df_all['miles'] <=1]
within_two=df_all[df_all['miles'] <=2]
within_three=df_all[df_all['miles'] <=3]
within_four=df_all[df_all['miles'] <=4]
within_five=df_all[df_all['miles'] <=5]
within_ten=df_all[df_all['miles'] <=10]

within_quarter
# Out:
#          Unnamed: 0        id   neighborhood_group       lat1        lon1  \
# 133             133      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 327             327      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 681             681      9419  OTHER NEIGHBORHOODS  47.550170 -122.319370
# 1489           1489      9531         WEST SEATTLE  47.554950 -122.386630
# 3283           3283      9596  OTHER NEIGHBORHOODS  47.656080 -122.336020
# ...             ...       ...                  ...        ...         ...
# 4074859     4074859  53904424             DOWNTOWN  47.614583 -122.348524
# 4074962     4074962  53904424             DOWNTOWN  47.614583 -122.348524
# 4074983     4074983  53904424             DOWNTOWN  47.614583 -122.348524
# 4075022     4075022  53904424             DOWNTOWN  47.614583 -122.348524
# 4075024     4075024  53904424             DOWNTOWN  47.614583 -122.348524
#
#                                    Title        Reviews Review_Points  \
# ...

# %%
within_quarter.describe()
# Out:
#          Unnamed: 0            id          lat1          lon1          lat2  \
# count  2.656900e+04  2.656900e+04  26569.000000  26569.000000  26569.000000
# mean   2.214999e+06  3.649730e+07     47.617978   -122.334386     47.617902
# std    1.133084e+06  1.639401e+07      0.021771      0.018021      0.021696
# min    1.330000e+02  9.419000e+03     47.512138   -122.417470     47.513429
# 25%    1.255457e+06  2.241064e+07     47.609670   -122.342890     47.609612
# 50%    2.427851e+06  4.423384e+07     47.613960   -122.337760     47.614077
# 75%    3.099585e+06  5.008694e+07     47.619350   -122.323130     47.620040
# max    4.075024e+06  5.390442e+07     47.733700   -122.257520     47.733506
#
#                lon2         miles
# count  26569.000000  26569.000000
# mean    -122.334368      0.162583
# std        0.017919      0.060002
# min     -122.413010      0.002173
# 25%     -122.343244      0.119476
# 50%     -122.337099      0.171071
# 75%     -122.322335      0.213872
# ...

# %%
#Groupby listing id. Gives count of points of interest within specified distance per airbnb listing, while preserving the neighborhood label.
within_quarter2=pd.DataFrame(within_quarter.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_half2=pd.DataFrame(within_half.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_one2=pd.DataFrame(within_one.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_two2=pd.DataFrame(within_two.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_three2=pd.DataFrame(within_three.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_four2=pd.DataFrame(within_four.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_five2=pd.DataFrame(within_five.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()
within_ten2=pd.DataFrame(within_ten.groupby(['id', 'neighborhood_group'])['miles'].count()).reset_index()

within_five2
# Out:
#             id   neighborhood_group  miles
# 0         9419  OTHER NEIGHBORHOODS    412
# 1         9531         WEST SEATTLE    311
# 2         9534         WEST SEATTLE    333
# 3         9596  OTHER NEIGHBORHOODS    596
# 4         9909         WEST SEATTLE    456
# ...        ...                  ...    ...
# 4679  53868263  OTHER NEIGHBORHOODS    598
# 4680  53881175         CENTRAL AREA    597
# 4681  53893335         CENTRAL AREA    576
# 4682  53901135             DELRIDGE    310
# 4683  53904424             DOWNTOWN    623
#
# [4684 rows x 3 columns]

# %%
halfdata=within_half2.copy()
onedata=within_one2.copy()
threedata=within_three2.copy()
fivedata=within_five2.copy()

halfdata=halfdata.rename(columns={'miles': 'within_half_mile'})
onedata=onedata.rename(columns={'miles': 'within_one_mile'})
threedata=threedata.rename(columns={'miles': 'within_three_miles'})
fivedata=fivedata.rename(columns={'miles': 'within_five_miles'})

df_one_three = pd.merge(onedata, threedata, on=['id', 'neighborhood_group'])
df_half_three = pd.merge(halfdata, df_one_three, on=['id', 'neighborhood_group'])
df_poi=pd.merge(df_half_three, fivedata, on=['id', 'neighborhood_group'])
df_poi.to_csv('assets/poi_by_listing.csv')

# %%
##Groupby neighborhood. Gives total sum of instances per neighborhood in which there is a point of interest within the designated distance of an airbnb location.

#quarter_group=pd.DataFrame(within_quarter2.groupby(['neighborhood_group'])["miles"].sum()).reset_index()
#half_group=pd.DataFrame(within_half2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#one_group=pd.DataFrame(within_one2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#two_group=pd.DataFrame(within_two2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#three_group=pd.DataFrame(within_three2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#four_group=pd.DataFrame(within_four2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#five_group=pd.DataFrame(within_five2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()
#ten_group=pd.DataFrame(within_ten2.groupby(["neighborhood_group"])["miles"].sum()).reset_index()

#Groupby neighborhood. Gives mean average number of points of interest within the designated distance of each airbnb location.
quarter_group=pd.DataFrame(within_quarter2.groupby(['neighborhood_group'])["miles"].mean().astype(int)).reset_index()
half_group=pd.DataFrame(within_half2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
one_group=pd.DataFrame(within_one2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
two_group=pd.DataFrame(within_two2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
three_group=pd.DataFrame(within_three2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
four_group=pd.DataFrame(within_four2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
five_group=pd.DataFrame(within_five2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()
ten_group=pd.DataFrame(within_ten2.groupby(["neighborhood_group"])["miles"].mean().astype(int)).reset_index()


neighborhood_dist_to_poi_counts=quarter_group.copy()
neighborhood_dist_to_poi_counts=neighborhood_dist_to_poi_counts.rename(columns={'miles': 'quarter_mile'})


neighborhood_dist_to_poi_counts['half_mile']=half_group['miles']
neighborhood_dist_to_poi_counts['one_mile']=one_group['miles']
neighborhood_dist_to_poi_counts['two_miles']=two_group['miles']
neighborhood_dist_to_poi_counts['three_miles']=three_group['miles']
neighborhood_dist_to_poi_counts['four_miles']=four_group['miles']
neighborhood_dist_to_poi_counts['five_miles']=five_group['miles']
neighborhood_dist_to_poi_counts['ten_miles']=ten_group['miles']

#ten_group
neighborhood_dist_to_poi_counts
# Out:
#      neighborhood_group  quarter_mile  half_mile  one_mile  two_miles  \
# 0               BALLARD             3          9        32         76
# 1           BEACON HILL             2          4        18         91
# 2          CAPITOL HILL             9         32       103        299
# 3               CASCADE             7         24       112        308
# 4          CENTRAL AREA             4         14        67        273
# 5              DELRIDGE             1          1         6         25
# 6              DOWNTOWN            23         71       197        346
# 7              INTERBAY             1          2        10         95
# 8             LAKE CITY             1          1         5         18
# 9              MAGNOLIA             1          2         9         63
# 10            NORTHGATE             1          2         8         38
# 11  OTHER NEIGHBORHOODS             2          7        25         87
# ...

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'quarter_mile', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('quarter_mile')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 1/4 Mile of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'half_mile', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('half_mile')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 1/2 Mile of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'one_mile', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('one_mile')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 1 Mile of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'two_miles', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('two_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 2 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'three_miles', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('three_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 3 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'four_miles', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('four_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 4 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'five_miles', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('five_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 5 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %%
#Scatterplot of the input data

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'ten_miles', y = 'neighborhood_group', data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('ten_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 10 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %% [markdown]
# KMeans clustering.
#
# KMeans is one of the simple but popular unsupervised learning algorithm. Here K indicates the number of clusters or classes the algorithm has to divide the data into. The algorithm starts with first group of randomly selected centroids, which are used as the beginning points for every cluster. It performs repetitive calculations to optimize the positions of the centroids.
#
# For more information visit- https://en.wikipedia.org/wiki/K-means_clustering

# %%
#Importing KMeans from sklearn

from sklearn.cluster import KMeans

# %%
neighborhood_dist_to_poi_counts.columns
# Out:
# Index(['neighborhood_group', 'quarter_mile', 'half_mile', 'one_mile',
#        'two_miles', 'three_miles', 'four_miles', 'five_miles', 'ten_miles'],
#       dtype='object')

# %%
# Now we calculate the Within Cluster Sum of Squared Errors (WSS) for different values of k. 
# Next, we choose the k for which WSS first starts to diminish.
X=neighborhood_dist_to_poi_counts[['quarter_mile', 'half_mile', 'one_mile', 'two_miles', 'three_miles', 'four_miles', 'five_miles', 'ten_miles']]
X
# Out:
#     quarter_mile  half_mile  one_mile  two_miles  three_miles  four_miles  \
# 0              3          9        32         76          141         231
# 1              2          4        18         91          210         305
# 2              9         32       103        299          440         532
# 3              7         24       112        308          458         555
# 4              4         14        67        273          402         495
# 5              1          1         6         25           63         152
# 6             23         71       197        346          432         519
# 7              1          2        10         95          218         457
# 8              1          1         5         18           50          97
# 9              1          2         9         63          153         339
# 10             1          2         8         38           96         164
# 11             2          7        25         87          193         326
# ...

# %%
wcss=[]

for i in range(1,10):
    km=KMeans(n_clusters=i)
    km.fit(X)
    wcss.append(km.inertia_)

# %%
#The elbow curve

plt.figure(figsize=(12,6))

plt.plot(range(1,10),wcss)

plt.plot(range(1,10),wcss, linewidth=2, color="red", marker ="8")

plt.xlabel("K Value")
plt.xticks(np.arange(1,10,1))
plt.ylabel("WCSS")

plt.show()

# %%
#this is known as the elbow graph , the x axis being the number of clusters
#the number of clusters is taken at the elbow joint point
#this point is the point where making clusters is most relevant
#the numbers of clusters is kept at maximum

# %%
#Taking 3 clusters

km1=KMeans(n_clusters=3, random_state=44)

# %%
#Fitting the input data

km1.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=44)

# %%
#predicting the labels of the input data

y=km1.predict(X)

# %%
#adding the labels to a column named label

neighborhood_dist_to_poi_counts["label"] = y

# %%
neighborhood_dist_to_poi_counts
# Out:
#      neighborhood_group  quarter_mile  half_mile  one_mile  two_miles  \
# 0               BALLARD             3          9        32         76
# 1           BEACON HILL             2          4        18         91
# 2          CAPITOL HILL             9         32       103        299
# 3               CASCADE             7         24       112        308
# 4          CENTRAL AREA             4         14        67        273
# 5              DELRIDGE             1          1         6         25
# 6              DOWNTOWN            23         71       197        346
# 7              INTERBAY             1          2        10         95
# 8             LAKE CITY             1          1         5         18
# 9              MAGNOLIA             1          2         9         63
# 10            NORTHGATE             1          2         8         38
# 11  OTHER NEIGHBORHOODS             2          7        25         87
# ...

# %%
#The new dataframe with the clustering done

neighborhood_dist_to_poi_counts['label'] = neighborhood_dist_to_poi_counts['label'].replace([1,2,0],['Fewest Nearby Choices','Moderate Nearby Choices','Most Nearby Choices'])

# %%
#Scatterplot of the clusters

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'five_miles',y = 'neighborhood_group',hue="label",
                 palette=['orange','dodgerblue','green'], legend="full",data = neighborhood_dist_to_poi_counts,s = 60 )
plt.xlabel('five_miles')
plt.ylabel('neighborhood_group')
plt.title('Mean Average Number of Points of Interest Within 5 Miles of Each Airbnb, by Neighborhood')
plt.show()

# %%
neighborhood_dist_to_poi_counts.to_csv('assets/neighborhood_dist_to_poi_counts_with_labels.csv')

# %%
pip install sqlalchemy --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import packages
import psycopg2
#import pandas as pd
from sqlalchemy import create_engine

# establish connections
conn_string = 'postgresql://jthkkecjvhqeso:c4615974e5b0f0e0424e8a84c51bf107d32bcff42927afa2285015e628b8b4bd@ec2-52-201-124-168.compute-1.amazonaws.com:5432/db6idd99el978g'

# create the engine with the connection string
db = create_engine(conn_string)

# this makes the connection to the PostgreSQL database
conn = db.connect()

# these are the credentials necessary to work with the PostgreSQL database
conn1 = psycopg2.connect(database='db6idd99el978g', user='jthkkecjvhqeso',
                         password='c4615974e5b0f0e0424e8a84c51bf107d32bcff42927afa2285015e628b8b4bd',
                         host='ec2-52-201-124-168.compute-1.amazonaws.com',
                         port= '5432')

conn1.autocommit = True

# create a cursor object
cursor = conn1.cursor()

# drop table if it already exists
cursor.execute('drop table if exists poi_proximity')

# create the SQL table – pick a unique name (don’t use dashes if more than one word
# use only underscores such as seattle_data or below is crime_clusters)
sql = '''CREATE TABLE poi_proximity(neighborhood_group varchar(128),tenth_mile varchar(128),quart_mile varchar(128));'''

# use cursor object to execute the sql create table command
cursor.execute(sql)

# converting data from pandas dataframe to sql
neighborhood_dist_to_poi_counts.to_sql('poi_proximity', conn, if_exists= 'replace')

# fetching all rows
sql1='''select * from poi_proximity;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)

# committing data from connection
conn1.commit()

# close connection to the postgresql database
conn1.close()
# Out:
# (0, 'BALLARD', 3, 9, 32, 76, 141, 231, 395, 734, 'Fewest Nearby Choices')
# (1, 'BEACON HILL', 2, 4, 18, 91, 210, 305, 406, 740, 'Moderate Nearby Choices')
# (2, 'CAPITOL HILL', 9, 32, 103, 299, 440, 532, 616, 774, 'Most Nearby Choices')
# (3, 'CASCADE', 7, 24, 112, 308, 458, 555, 621, 770, 'Most Nearby Choices')
# (4, 'CENTRAL AREA', 4, 14, 67, 273, 402, 495, 582, 777, 'Most Nearby Choices')
# (5, 'DELRIDGE', 1, 1, 6, 25, 63, 152, 264, 695, 'Fewest Nearby Choices')
# (6, 'DOWNTOWN', 23, 71, 197, 346, 432, 519, 616, 770, 'Most Nearby Choices')
# (7, 'INTERBAY', 1, 2, 10, 95, 218, 457, 572, 756, 'Moderate Nearby Choices')
# (8, 'LAKE CITY', 1, 1, 5, 18, 50, 97, 161, 690, 'Fewest Nearby Choices')
# (9, 'MAGNOLIA', 1, 2, 9, 63, 153, 339, 521, 744, 'Moderate Nearby Choices')
# (10, 'NORTHGATE', 1, 2, 8, 38, 96, 164, 236, 711, 'Fewest Nearby Choices')
# (11, 'OTHER NEIGHBORHOODS', 2, 7, 25, 87, 193, 326, 459, 747, 'Moderate Nearby Choices')
# ...

# %%
# Now printing the ID according to the groups

grp1=neighborhood_dist_to_poi_counts[neighborhood_dist_to_poi_counts["label"]=='Fewest Nearby Choices']
print('Number of neighborhood groups in Fewest Nearby Choices: ', len(grp1))

print("--------------------------------------------")
grp2=neighborhood_dist_to_poi_counts[neighborhood_dist_to_poi_counts["label"]=='Moderate Nearby Choices']
print('Number of neighborhood groups in Moderate Nearby Choices: ', len(grp2))

print("--------------------------------------------")
grp3=neighborhood_dist_to_poi_counts[neighborhood_dist_to_poi_counts["label"]=='Most Nearby Choices']
print('Number of neighborhood groups in Most Nearby Choices: ', len(grp3))

print("--------------------------------------------")
# Out:
# Number of neighborhood groups in Fewest Nearby Choices:  7
# --------------------------------------------
# Number of neighborhood groups in Moderate Nearby Choices:  5
# --------------------------------------------
# Number of neighborhood groups in Most Nearby Choices:  5
# --------------------------------------------
